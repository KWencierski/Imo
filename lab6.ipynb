# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import random
import copy
import time

# %%
def distance(a, b):
    return round(np.sqrt(( a[0] - b[0])**2 + (a[1]) - b[1])**2)

def calc_distance_sum(cycle, distance_matrix):
    suma = 0
    for i in range(1, len(cycle)):
        suma += distance_matrix[cycle[i-1], cycle[i]]
    return suma

# %%
def plot_results(cycles, points_matrix):
    plt.scatter(points_matrix[..., 0], points_matrix[..., 1])
    plt.plot(points_matrix[cycles[0], 0], points_matrix[cycles[0], 1], 'r')
    plt.plot(points_matrix[cycles[1], 0], points_matrix[cycles[1], 1], 'g')
    plt.show()

def plot_results2(cycles, cycles2, points_matrix):
    plt.scatter(points_matrix[..., 0], points_matrix[..., 1])
    plt.plot(points_matrix[cycles[1], 0], points_matrix[cycles[1], 1], 'g')
    plt.plot(points_matrix[cycles[0], 0], points_matrix[cycles[0], 1], 'r')

    plt.plot(points_matrix[cycles2[1], 0], points_matrix[cycles2[1], 1], 'b')
    plt.plot(points_matrix[cycles2[0], 0], points_matrix[cycles2[0], 1], 'orange')

    plt.show()

def plot_results3(cycles, cycles2, points_matrix):
    ax, fig = plt.subplots(1, 3, figsize=(15, 5))
    fig[0].scatter(points_matrix[..., 0], points_matrix[..., 1])
    fig[0].plot(points_matrix[cycles[1], 0], points_matrix[cycles[1], 1], 'g')
    fig[0].plot(points_matrix[cycles[0], 0], points_matrix[cycles[0], 1], 'r')

    fig[1].scatter(points_matrix[..., 0], points_matrix[..., 1])
    fig[1].plot(points_matrix[cycles2[1], 0], points_matrix[cycles2[1], 1], 'b')
    fig[1].plot(points_matrix[cycles2[0], 0], points_matrix[cycles2[0], 1], 'orange')

    fig[2].scatter(points_matrix[..., 0], points_matrix[..., 1])
    fig[2].plot(points_matrix[cycles[1], 0], points_matrix[cycles[1], 1], 'g')
    fig[2].plot(points_matrix[cycles[0], 0], points_matrix[cycles[0], 1], 'r')
    fig[2].plot(points_matrix[cycles2[1], 0], points_matrix[cycles2[1], 1], 'b')
    fig[2].plot(points_matrix[cycles2[0], 0], points_matrix[cycles2[0], 1], 'orange')
    plt.show()

# %%
def solve_cycle(distance_matrix, start = -1):
    remaining = [i for i in range(distance_matrix.shape[0])]
    if start == -1:
        x = np.random.choice(remaining)
    else:
        x = start
    first_cycle = [x]
    remaining.remove(x)
    ind = np.argpartition(distance_matrix[x,:], -2)[-2:]
    second_x = ind.tolist()
    second_x.remove(x)
    second_x = second_x[0]
    second_cycle = [second_x]
    remaining.remove(second_x)

    cycles = [first_cycle, second_cycle]

    for cycle in cycles:
        min_node = remaining[np.argmin(distance_matrix[cycle[-1]][remaining])]
        cycle.append(min_node)
        remaining.remove(min_node)

    while remaining:
        for cycle in cycles:
            cycle.append(cycle[0])
            best_node = None
            lowest_distance_increase = np.inf
            best_index = None

            for i in range(len(cycle) - 1):
                for remaining_node in remaining:
                    distance_increase = distance_matrix[cycle[i]][remaining_node] + distance_matrix[remaining_node][cycle[i+1]] - distance_matrix[cycle[i]][cycle[i+1]]
                    if distance_increase < lowest_distance_increase:
                        lowest_distance_increase = distance_increase
                        best_node = remaining_node
                        best_index = i

            cycle.insert(best_index + 1, best_node)
            # plot_results(cycles)
            remaining.remove(best_node)
            cycle.pop()

    for cycle in cycles:
        cycle.append(cycle[0])
    return cycles

def solve_random(distance_matrix):
    remaining = [i for i in range(distance_matrix.shape[0])]
    cycles = [[], []]
    append_to_cycle = 0
    while len(remaining) > 0:
        x = np.random.choice(remaining)
        cycles[append_to_cycle].append(x)
        remaining.remove(x)
        append_to_cycle = 1 - append_to_cycle

    for cycle in cycles:
        cycle.append(cycle[0])
    return cycles

# %%
def shuffled_outside_swap_candidates(paths):
    arr = [[x,y] for x in range(len(paths[0])) for y in range(len(paths[1]))]
    random.shuffle(arr)
    return arr

def shuffled_inside_swap_candidates(path):
    arr = []
    for i in range(len(path)):
        for j in range(i+1, len(path) - 1):
            arr.append([i,j])
    random.shuffle(arr)
    return arr

def swap_vertice_cost(distance_matrix, path, index, new_city):
    path_length = len(path)
    previous = path[(index-1) % path_length]
    current = path[index]
    next = path[(index+1) % path_length]
    return distance_matrix[previous, new_city] + distance_matrix[new_city, next] - distance_matrix[previous, current] - distance_matrix[current, next]

def swap_vertice_outside_cost(distance_matrix, paths, i, j):
    return swap_vertice_cost(distance_matrix, paths[0], i, paths[1][j]) + swap_vertice_cost(distance_matrix, paths[1], j, paths[0][i])

def swap_vertice_inside_cost(distance_matrix, path, i, j): # can only use candidates from shuffled_inside_swap_candidates function
    path_length = len(path)
    previous1 = path[(i-1) % path_length]
    current1 = path[i]
    next1 = path[(i+1) % path_length]
    previous2 = path[(j-1) % path_length]
    current2 = path[j]
    next2 = path[(j+1) % path_length]
    if abs(i-j) == 1: # because if they are neighbours they can become each other next vertex in path, we also dont include distance between them in equation because it would be reduced anyway
        return distance_matrix[previous1, current2] + distance_matrix[current1, next2] - distance_matrix[previous1, current1] - distance_matrix[current2, next2]
    if i in [0, path_length-1] and j in [0, path_length-1]:
        return distance_matrix[current2, next1] + distance_matrix[previous2, current1] - distance_matrix[current1, next1] - distance_matrix[previous2, current2]
    else:
        new_distance = distance_matrix[previous1, current2] + distance_matrix[current2, next1] + distance_matrix[previous2, current1] + distance_matrix[current1, next2]
        old_distance = distance_matrix[previous1, current1] + distance_matrix[current1, next1] + distance_matrix[previous2, current2] + distance_matrix[current2, next2]
        return new_distance - old_distance

def swap_edge_inside_cost(distance_matrix, path, i, j):
    if i == 0 and j == len(path) - 2:
        return 0
    path_length = len(path)
    previous1 = path[(i-1) % path_length]
    current1 = path[i]
    current2 = path[j]
    next2 = path[(j+1) % path_length]
    return distance_matrix[previous1, current2] + distance_matrix[current1, next2] - distance_matrix[previous1, current1] - distance_matrix[current2, next2]

def swap_vertice_outside(paths, i, j):
    k = paths[1][j]
    paths[1][j] = paths[0][i]
    paths[0][i] = k

def swap_vertice_inside(path, i, j):
    k = path[j]
    path[j] = path[i]
    path[i] = k

def swap_edges_inside(path, i, j):
    if i > j:
        i, j = j, i

    path[i:j+1] = reversed(path[i:j+1])

def solve_greedy(distance_matrix, initial_cycles, neighborhood='vertex'):
    cycles = copy.deepcopy(initial_cycles)
    cycles[0].pop()
    cycles[1].pop()
    outside_checked = False
    inside_checked = False
    if neighborhood == 'vertex':
        while not (outside_checked and inside_checked):
            new_change_found = False
            if (not outside_checked and inside_checked) or (not outside_checked and np.random.random() < 0.5):
                outside_swap_candidates = shuffled_outside_swap_candidates(cycles)
                for candidates in outside_swap_candidates:
                    delta = swap_vertice_outside_cost(distance_matrix, cycles, candidates[0], candidates[1])
                    if delta < 0:
                        swap_vertice_outside(cycles, candidates[0], candidates[1])
                        new_change_found = True
                        break
                if new_change_found:
                    outside_checked = False
                    inside_checked = False
                    continue
                outside_checked = True
            if not inside_checked:
                order = np.arange(len(cycles))
                np.random.shuffle(order)
                for i in order:
                    inside_swap_candidates = shuffled_inside_swap_candidates(cycles[i])
                    for candidates in inside_swap_candidates:
                        delta = swap_vertice_inside_cost(distance_matrix, cycles[i], candidates[0], candidates[1])
                        if delta < 0:
                            swap_vertice_inside(cycles[i], candidates[0], candidates[1])
                            new_change_found = True
                            break
                if new_change_found:
                    outside_checked = False
                    inside_checked = False
                    continue
                inside_checked = True
    else:
        while not (outside_checked and inside_checked):
            new_change_found = False
            if (not outside_checked and inside_checked) or (not outside_checked and np.random.random() < 0.5):
                outside_swap_candidates = shuffled_outside_swap_candidates(cycles)
                for candidates in outside_swap_candidates:
                    delta = swap_vertice_outside_cost(distance_matrix, cycles, candidates[0], candidates[1])
                    if delta < -1e-7:
                        # print(f'outside swap {candidates[0]} {candidates[1]} {delta}')
                        swap_vertice_outside(cycles, candidates[0], candidates[1])
                        new_change_found = True
                        break
                if new_change_found:
                    outside_checked = False
                    inside_checked = False
                    continue
                outside_checked = True
            if not inside_checked:
                order = np.arange(len(cycles))
                np.random.shuffle(order)
                for i in order:
                    inside_swap_candidates = shuffled_inside_swap_candidates(cycles[i])
                    for candidates in inside_swap_candidates:
                        delta = swap_edge_inside_cost(distance_matrix, cycles[i], candidates[0], candidates[1])
                        if delta < -1e-7:
                            # print(f'inside swap {i} {candidates[0]} {candidates[1]} {delta}')
                            swap_edges_inside(cycles[i], candidates[0], candidates[1])
                            new_change_found = True
                            break
                if new_change_found:
                    outside_checked = False
                    inside_checked = False
                    continue
                inside_checked = True

    for cycle in cycles:
        cycle.append(cycle[0])
    return cycles

def solve_steepest(distance_matrix, initial_cycles, neighborhood='edge'):
    cycles = copy.deepcopy(initial_cycles)
    cycles[0].pop()
    cycles[1].pop()

    new_change_found = True
    best_candidates = None
    is_change_outside = None
    best_cycle_index = 0
    if neighborhood == 'vertex':
        while new_change_found:
            new_change_found = False
            best_delta = np.inf
            outside_swap_candidates = shuffled_outside_swap_candidates(cycles)
            for candidates in outside_swap_candidates:
                delta = swap_vertice_outside_cost(distance_matrix, cycles, candidates[0], candidates[1])
                if delta < 0 and delta < best_delta:
                    best_delta = delta
                    best_candidates = [candidates[0], candidates[1]]
                    is_change_outside = True
                    new_change_found = True

            for i in range(len(cycles)):
                inside_swap_candidates = shuffled_inside_swap_candidates(cycles[i])
                for candidates in inside_swap_candidates:
                    delta = swap_vertice_inside_cost(distance_matrix, cycles[i], candidates[0], candidates[1])
                    if delta < 0 and delta < best_delta:
                        best_delta = delta
                        best_candidates = [candidates[0], candidates[1]]
                        best_cycle_index = i
                        is_change_outside = False
                        new_change_found = True

            if new_change_found:
                if is_change_outside:
                    swap_vertice_outside(cycles, best_candidates[0], best_candidates[1])
                else:
                    swap_vertice_inside(cycles[best_cycle_index], best_candidates[0], best_candidates[1])

    else:
        while new_change_found:
            new_change_found = False
            best_delta = np.inf
            outside_swap_candidates = shuffled_outside_swap_candidates(cycles)
            for candidates in outside_swap_candidates:
                delta = swap_vertice_outside_cost(distance_matrix, cycles, candidates[0], candidates[1])
                if delta < 0 and delta < best_delta:
                    best_delta = delta
                    best_candidates = [candidates[0], candidates[1]]
                    is_change_outside = True
                    new_change_found = True

            for i in range(len(cycles)):
                inside_swap_candidates = shuffled_inside_swap_candidates(cycles[i])
                for candidates in inside_swap_candidates:
                    delta = swap_edge_inside_cost(distance_matrix, cycles[i], candidates[0], candidates[1])
                    if delta < 0 and delta < best_delta:
                        best_delta = delta
                        best_candidates = [candidates[0], candidates[1]]
                        best_cycle_index = i
                        is_change_outside = False
                        new_change_found = True

            if new_change_found:
                if is_change_outside:
                    swap_vertice_outside(cycles, best_candidates[0], best_candidates[1])
                else:
                    swap_vertice_inside(cycles[best_cycle_index], best_candidates[0], best_candidates[1])

    for cycle in cycles:
        cycle.append(cycle[0])
    return cycles

# %%
def swap_edge_inside_cost2(distance_matrix, path, i, j):
    if i > j:
        i, j = j, i
    delta1 = swap_edge_inside_cost(distance_matrix, path, (i+1) % len(path), j)
    delta2 = swap_edge_inside_cost(distance_matrix, path, i, (j-1) % len(path))
    if delta1 < delta2:
        return delta1, (i+1) % len(path), j
    else:
        return delta2, i, (j-1) % len(path)

def solve_cadidates(distance_matrix, initial_cycles, number_of_candidates=10):
    cycles = copy.deepcopy(initial_cycles)
    cycles[0].pop()
    cycles[1].pop()

    new_change_found = True
    while new_change_found:
        new_change_found = False
        best_candidates = None
        is_change_outside = None
        best_cycle_index = 0
        best_delta = np.inf
        for node in range(distance_matrix.shape[0]):
            node_cycle_index = 0 if node in cycles[0] else 1
            node_index = cycles[node_cycle_index].index(node)
            closest_nodes = np.argsort(distance_matrix[node])[1: number_of_candidates+1]
            for candidate in closest_nodes:
                candidate_cycle_index = 0 if candidate in cycles[0] else 1
                if node_cycle_index != candidate_cycle_index:
                    candidate_index = cycles[candidate_cycle_index].index(candidate)
                    if node_cycle_index == 0:
                        node_1, node_2 = node_index, candidate_index
                    else:
                        node_1, node_2 = candidate_index, node_index
                    delta = swap_vertice_outside_cost(distance_matrix, cycles, node_1, node_2)
                    if delta < -1e-5 and delta < best_delta:
                        best_delta = delta
                        best_candidates = [node_1, node_2]
                        is_change_outside = True
                        new_change_found = True
                else:
                    candidate_index = cycles[node_cycle_index].index(candidate)
                    if node_index < candidate_index:
                        node_1, node_2 = node_index, candidate_index
                    else:
                        node_1, node_2 = candidate_index, node_index
                    delta, node_1, node_2 = swap_edge_inside_cost2(distance_matrix, cycles[node_cycle_index], node_1, node_2)
                    if delta < -1e-5 and delta < best_delta:
                        best_delta = delta
                        best_candidates = [node_1, node_2]
                        best_cycle_index = node_cycle_index
                        is_change_outside = False
                        new_change_found = True
        if new_change_found:
            # print(best_delta, best_candidates, is_change_outside)
            # print(best_candidates)
            if is_change_outside:
                swap_vertice_outside(cycles, best_candidates[0], best_candidates[1])
            else:
                swap_edges_inside(cycles[best_cycle_index], best_candidates[0], best_candidates[1])
    for cycle in cycles:
        cycle.append(cycle[0])
    return cycles

def solve_msls(distance_matrix, local_search, number_of_iterations=100):
    best_distance = np.inf
    best_cycles = None
    for i in range(number_of_iterations):
        print(f'Iteration {i}')
        starting_cycles = solve_random(distance_matrix)
        cycles = local_search(distance_matrix, starting_cycles, neighborhood='edges')
        distance = calc_distance_sum(cycles[0], distance_matrix) + calc_distance_sum(cycles[1], distance_matrix)
        if distance < best_distance:
            best_distance = distance
            best_cycles = copy.deepcopy(cycles)
    return best_cycles


def apply_perturbation(cycles, distance_matrix):
    cycles[0].pop()
    cycles[1].pop()
    if np.random.rand() < 0.5:
        # swap two vertices between cycles
        cycle_1 = 0
        cycle_2 = 1
        vertice_1 = np.random.randint(len(cycles[cycle_1]))
        vertice_2 = np.random.randint(len(cycles[cycle_2]))
        # print(cycle_1, vertice_1, cycle_2, vertice_2)
        swap_vertice_outside(cycles, vertice_1, vertice_2)
    else:
        # swap two vertices inside one cycle
        cycle = np.random.randint(2)
        vertice_1 = np.random.randint(len(cycles[cycle]))
        vertice_2 = np.random.randint(len(cycles[cycle]))
        # print(cycle, vertice_1, vertice_2)
        swap_vertice_inside(cycles[cycle], vertice_1, vertice_2)
    cycles[0].append(cycles[0][0])
    cycles[1].append(cycles[1][0])
    return cycles


def solve_ils1(distance_matrix, local_search, number_of_perturbations, time_limit, points_matrix):
    time_remaining = time_limit
    start_time = time.time()
    starting_cycles = solve_random(distance_matrix)
    cycles = local_search(distance_matrix, starting_cycles, neighborhood='edges')
    # plot_results(cycles, points_matrix)
    best_distance = calc_distance_sum(cycles[0], distance_matrix) + calc_distance_sum(cycles[1], distance_matrix)
    best_cycles = copy.deepcopy(cycles)
    while time_remaining > 0:
        # print(f'time remaining {time_remaining}')
        # cycles_copy = copy.deepcopy(cycles)
        for _ in range(number_of_perturbations):
            cycles = apply_perturbation(cycles, distance_matrix)
        # plot_results3(cycles_copy, cycles, points_matrix)
        cycles = local_search(distance_matrix, cycles, neighborhood='edges')
        distance = calc_distance_sum(cycles[0], distance_matrix) + calc_distance_sum(cycles[1], distance_matrix)
        if distance < best_distance:
            best_distance = distance
            best_cycles = copy.deepcopy(cycles)
        time_remaining = time_limit - (time.time() - start_time)
    return best_cycles

# %%
def apply_big_perturbation(cycles, distance_matrix, percent_affected = 0.2):
    destroy_sequence_length = int(len(cycles[0]) * percent_affected)
    remaining_vertices = []
    for cycle in cycles:
        cycle.pop()
        assert len(cycle) > destroy_sequence_length + 1, "Percent affected is too big"
        starting_index = np.random.randint(len(cycle)- destroy_sequence_length)
        remaining_vertices += cycle[starting_index: starting_index + destroy_sequence_length]
        cycle[starting_index: starting_index + destroy_sequence_length] = []

    while remaining_vertices:
        for cycle in cycles:
            cycle.append(cycle[0])
            best_node = None
            lowest_distance_increase = np.inf
            best_index = None

            for i in range(len(cycle) - 1):
                for remaining_node in remaining_vertices:
                    distance_increase = distance_matrix[cycle[i]][remaining_node] + distance_matrix[remaining_node][cycle[i+1]] - distance_matrix[cycle[i]][cycle[i+1]]
                    if distance_increase < lowest_distance_increase:
                        lowest_distance_increase = distance_increase
                        best_node = remaining_node
                        best_index = i

            cycle.insert(best_index + 1, best_node)
            # plot_results(cycles)
            remaining_vertices.remove(best_node)
            cycle.pop()

    for cycle in cycles:
        cycle.append(cycle[0])
    
    # print(f"distances = {calc_distance_sum(cycles[0], distance_matrix) + calc_distance_sum(cycles[1], distance_matrix)}")
    return cycles

            

def solve_ils2(distance_matrix, local_search, number_of_perturbations, time_limit, points_matrix):
    time_remaining = time_limit
    start_time = time.time()
    starting_cycles = solve_random(distance_matrix)
    cycles = local_search(distance_matrix, starting_cycles, neighborhood='edges')
    # plot_results(cycles, points_matrix)
    best_distance = calc_distance_sum(cycles[0], distance_matrix) + calc_distance_sum(cycles[1], distance_matrix)
    best_cycles = copy.deepcopy(cycles)
    while time_remaining > 0:
        # print(f'time remaining {time_remaining}')
        # cycles_copy = copy.deepcopy(cycles)
        for _ in range(number_of_perturbations):
            cycles = apply_big_perturbation(cycles, distance_matrix)
        # plot_results3(cycles_copy, cycles, points_matrix)
        cycles = local_search(distance_matrix, cycles, neighborhood='edges')
        distance = calc_distance_sum(cycles[0], distance_matrix) + calc_distance_sum(cycles[1], distance_matrix)
        if distance < best_distance:
            best_distance = distance
            best_cycles = copy.deepcopy(cycles)
        time_remaining = time_limit - (time.time() - start_time)
    return best_cycles

def repair_cycles(distance_matrix, cycles):
    remaining = [i for i in range(distance_matrix.shape[0]) if i not in cycles[0] and i not in cycles[1]]
    # print(len(cycles[0]), len(cycles[1]), len(remaining))

    for cycle in cycles:
        if cycle[0] == cycle[-1]:
            cycle.pop()

    while remaining:
        for cycle in cycles:
            if len(cycle) >= distance_matrix.shape[0]:
                continue
            cycle.append(cycle[0])
            best_node = None
            lowest_distance_increase = np.inf
            best_index = None

            for i in range(len(cycle) - 1):
                for remaining_node in remaining:
                    distance_increase = distance_matrix[cycle[i]][remaining_node] + distance_matrix[remaining_node][cycle[i+1]] - distance_matrix[cycle[i]][cycle[i+1]]
                    # print(lowest_distance_increase, distance_increase)
                    if distance_increase < lowest_distance_increase:
                        lowest_distance_increase = distance_increase
                        best_node = remaining_node
                        best_index = i

            if best_node is None:
                continue
            # print(best_node, best_index)
            cycle.insert(best_index + 1, best_node)
            # plot_results(cycles)
            remaining.remove(best_node)
            cycle.pop()

    for cycle in cycles:
        cycle.append(cycle[0])
    return cycles

def recombination(distance_matrix, parent1, parent2):
    # for every cycle in child remove sequences of vertices that are not in parent2
    nodes_to_remove = []
    for cycle_index, cycle in enumerate(parent1):
        # print(cycle)
        for i in range(len(cycle)):
            # print(cycle[i])
            if cycle[i] not in parent2[cycle_index]:
                nodes_to_remove.append(i)
                continue
            pos_in_parent2 = parent2[cycle_index].index(cycle[i])
            if parent2[cycle_index][(pos_in_parent2 + 1) % len(cycle)] != cycle[(i + 1) % len(cycle)]:
                nodes_to_remove.append(i)

    child = []
    for cycle_index in range(2):
        new_cycle = []
        for i in parent1[cycle_index]:
            if i not in nodes_to_remove and np.random.rand() < 0.85:
                new_cycle.append(i)
        child.append(new_cycle)

    child = repair_cycles(distance_matrix, child)
    return child

def solve_evo(distance_matrix, max_time):
    start_time = time.time()
    population_size = 20
    elite_size = 10  # TODO - ustalić
    # max_generations = 100
    
    population = []
    elite_population = []
    initial_cycles = solve_random(distance_matrix)

    best_distance = np.inf
    best_cycles = None
    
    # Generowanie początkowej populacji
    for i in range(population_size):
        print(f'Generating initial population {i}')
        cycles = solve_greedy(distance_matrix, initial_cycles, neighborhood='edges')
        population.append(cycles)
    
    # for generation in range(max_generations):
    generation = 0
    while time.time() - start_time < max_time:
        # Obliczanie wartości funkcji celu dla każdego rozwiązania
        distances = [calc_distance_sum(solution[0], distance_matrix) + calc_distance_sum(solution[1], distance_matrix) for solution in population]
        
        # Sortowanie populacji na podstawie wartości funkcji celu
        sorted_indices = np.argsort(distances)
        sorted_population = [population[i] for i in sorted_indices]
        
        # Przenoszenie najlepszych osobników do populacji elitarnej
        elite_population = sorted_population[:elite_size]

        # plot_results(elite_population[0], distance_matrix)
        if distances[sorted_indices[0]] < best_distance:
            best_distance = distances[sorted_indices[0]]
            best_cycles = copy.deepcopy(elite_population[0])
        generation += 1
        print(f'New best distance: {best_distance} in generation {generation}')
        
        # Sprawdzanie czy osiągnięto warunek zakończenia
        # if termination_condition():  # TODO
            # break
        
        # Operator rekombinacji - tworzenie nowej populacji
        new_population = []
        while len(new_population) < population_size:
            parent1 = random.choice(elite_population)
            parent2 = random.choice(elite_population)
            
            child = recombination(distance_matrix, parent1, parent2)
            
            # Dodawanie potomka do nowej populacji
            if child not in new_population:
                new_population.append(child)
        
        # Aktualizacja populacji
        population = new_population

    return best_cycles

# %%
# instances = ['./data/lab1/kroA100.txt', './data/lab1/kroB100.txt']
instances = ['./data/lab3/kroA200.txt', './data/lab3/kroB200.txt']
instance_size = 200
strategies = [solve_msls]

def get_results_msls():
    results = []
    times = []
    for instance in instances:
        with open(instance) as f:
            data = f.read()
        data = data.split('\n')
        data = pd.DataFrame([i.split(' ') for i in data])
        data = data.drop(0, axis=1)
        data = data.drop(instance_size, axis=0)

        points_matrix = data.to_numpy()
        points_matrix = points_matrix.astype(int)
        matrix = []
        for i in range(instance_size):
            matrix.append([])
            for j in range(instance_size):
                matrix[i].append(points_matrix[i, :] - points_matrix[j, :])
        matrix = np.array(matrix)
        distance_matrix = np.sqrt(np.square(matrix[:, :, 0]) + np.square(matrix[:, :, 1]))

        for i in range(distance_matrix.shape[0]):
            distance_matrix[i, i] = np.inf

        for strategy in strategies:
            distances = []
            algorithm_times = []
            best_cycles = None
            best_distance = np.inf
            # for i in range(distance_matrix.shape[0]):
            for i in range(10):
                print(f'Intance: {instance}, strategy: {strategy.__name__}, node: {i}')
                start_time = time.time()
                cycles = strategy(distance_matrix, solve_greedy, number_of_iterations=100)
                algorithm_times.append(time.time() - start_time)
                distances.append(calc_distance_sum(cycles[0], distance_matrix) + calc_distance_sum(cycles[1], distance_matrix))
                if distances[-1] < best_distance:
                    best_distance = distances[-1]
                    best_cycles = copy.deepcopy(cycles)
            times.append(dict(instance=instance, strategy=strategy.__name__, min_time=min(algorithm_times), mean_time=np.mean(algorithm_times), max_time=max(algorithm_times)))
            results.append(dict(instance=instance, strategy=strategy.__name__, min_distance=min(distances), mean_distance=np.mean(distances), max_distance=max(distances)))
            print(f'Intance: {instance}, strategy: {strategy.__name__}, best_distance: {best_distance}')
            plot_results(best_cycles, points_matrix)
    return results, times

# %%
results_msls, times_msls = get_results_msls()
# Out:
# Intance: ./data/lab3/kroA200.txt, strategy: solve_msls, node: 0
# Iteration 0
# Iteration 1
# Iteration 2
# Iteration 3
# Iteration 4
# Iteration 5
# Iteration 6
# Iteration 7
# Iteration 8
# Iteration 9
# Iteration 10
# Iteration 11
# Iteration 12
# Iteration 13
# Iteration 14
# Iteration 15
# Iteration 16
# Iteration 17
# Iteration 18
# Iteration 19
# Iteration 20
# Iteration 21
# Iteration 22
# Iteration 23
# Iteration 24
# Iteration 25
# Iteration 26
# Iteration 27
# Iteration 28
# Iteration 29
# Iteration 30
# Iteration 31
# Iteration 32
# Iteration 33
# Iteration 34
# Iteration 35
# Iteration 36
# Iteration 37
# Iteration 38
# Iteration 39
# Iteration 40
# Iteration 41
# Iteration 42
# Iteration 43
# Iteration 44
# Iteration 45
# Iteration 46
# Iteration 47
# Iteration 48
# Iteration 49
# Iteration 50
# Iteration 51
# Iteration 52
# Iteration 53
# Iteration 54
# Iteration 55
# Iteration 56
# Iteration 57
# Iteration 58
# Iteration 59
# Iteration 60
# Iteration 61
# Iteration 62
# Iteration 63
# Iteration 64
# Iteration 65
# Iteration 66
# Iteration 67
# Iteration 68
# Iteration 69
# Iteration 70
# Iteration 71
# Iteration 72
# Iteration 73
# Iteration 74
# Iteration 75
# Iteration 76
# Iteration 77
# Iteration 78
# Iteration 79
# Iteration 80
# Iteration 81
# Iteration 82
# Iteration 83
# Iteration 84
# Iteration 85
# Iteration 86
# Iteration 87
# Iteration 88
# Iteration 89
# Iteration 90
# Iteration 91
# Iteration 92
# Iteration 93
# Iteration 94
# Iteration 95
# Iteration 96
# Iteration 97
# Iteration 98
# Iteration 99
# Intance: ./data/lab3/kroA200.txt, strategy: solve_msls, node: 1
# Iteration 0
# Iteration 1
# Iteration 2
# Iteration 3
# Iteration 4
# Iteration 5
# Iteration 6
# Iteration 7
# Iteration 8
# Iteration 9
# Iteration 10
# Iteration 11
# Iteration 12
# Iteration 13
# Iteration 14
# Iteration 15
# Iteration 16
# Iteration 17
# Iteration 53
# Iteration 54
# Iteration 55
# Iteration 56
# Iteration 57
# Iteration 58
# Iteration 59
# Iteration 60
# Iteration 61
# Iteration 62
# Iteration 63
# Iteration 64
# Iteration 65
# Iteration 66
# Iteration 67
# Iteration 68
# Iteration 69
# Iteration 70
# Iteration 71
# Iteration 72
# Iteration 73
# Iteration 74
# Iteration 75
# Iteration 76
# Iteration 77
# Iteration 78
# Iteration 79
# Iteration 80
# Iteration 81
# Iteration 82
# Iteration 83
# Iteration 84
# Iteration 85
# Iteration 86
# Iteration 87
# Iteration 88
# Iteration 89
# Iteration 90
# Iteration 91
# Iteration 92
# Iteration 93
# Iteration 94
# Iteration 95
# Iteration 96
# Iteration 97
# Iteration 98
# Iteration 99
# Intance: ./data/lab3/kroB200.txt, strategy: solve_msls, best_distance: 35491.5883850667

# %%
pd.DataFrame(results_msls)
# Out:
#                   instance    strategy  min_distance  mean_distance  \
# 0  ./data/lab3/kroA200.txt  solve_msls  35498.673943   36006.531427
# 1  ./data/lab3/kroB200.txt  solve_msls  35491.588385   36122.882108
#
#    max_distance
# 0  36847.047220
# 1  36525.033127

# %%
pd.DataFrame(times_msls)
# Out:
#                   instance    strategy    min_time   mean_time    max_time
# 0  ./data/lab3/kroA200.txt  solve_msls  403.983396  411.651582  432.836930
# 1  ./data/lab3/kroB200.txt  solve_msls  403.087712  409.593272  413.608258

# %%
# instances = ['./data/lab1/kroA100.txt', './data/lab1/kroB100.txt']
instances = ['./data/lab3/kroA200.txt', './data/lab3/kroB200.txt']
# instances = ['./data/lab3/kroA200.txt']
instance_size = 200
# instance_size = 100
strategies = [solve_evo]

def get_results():
    results = []
    times = []
    for instance in instances:
        with open(instance) as f:
            data = f.read()
        data = data.split('\n')
        data = pd.DataFrame([i.split(' ') for i in data])
        data = data.drop(0, axis=1)
        data = data.drop(instance_size, axis=0)

        points_matrix = data.to_numpy()
        points_matrix = points_matrix.astype(int)
        # print(np.max(points_matrix[:, 1]))
        matrix = []
        for i in range(instance_size):
            matrix.append([])
            for j in range(instance_size):
                matrix[i].append(points_matrix[i, :] - points_matrix[j, :])
        matrix = np.array(matrix)
        distance_matrix = np.sqrt(np.square(matrix[:, :, 0]) + np.square(matrix[:, :, 1]))

        for i in range(distance_matrix.shape[0]):
            distance_matrix[i, i] = np.inf

        for strategy in strategies:
            distances = []
            algorithm_times = []
            best_cycles = None
            best_distance = np.inf
            # for i in range(distance_matrix.shape[0]):
            for i in range(5):
                print(f'Intance: {instance}, strategy: {strategy.__name__}, node: {i}')
                start_time = time.time()
                # cycles = strategy(distance_matrix, solve_greedy, 10, 411.651582, points_matrix)
                cycles = strategy(distance_matrix, 411.651582)
                algorithm_times.append(time.time() - start_time)
                distances.append(calc_distance_sum(cycles[0], distance_matrix) + calc_distance_sum(cycles[1], distance_matrix))
                if distances[-1] < best_distance:
                    best_distance = distances[-1]
                    best_cycles = copy.deepcopy(cycles)
            times.append(dict(instance=instance, strategy=strategy.__name__, min_time=min(algorithm_times), mean_time=np.mean(algorithm_times), max_time=max(algorithm_times)))
            results.append(dict(instance=instance, strategy=strategy.__name__, min_distance=min(distances), mean_distance=np.mean(distances), max_distance=max(distances)))
            print(f'Intance: {instance}, strategy: {strategy.__name__}, best_distance: {best_distance}')
            plot_results(best_cycles, points_matrix)
    return results, times

# %%
results_ils1, times_ils1 = get_results()
# Out:
# Intance: ./data/lab3/kroA200.txt, strategy: solve_evo, node: 0
# Generating initial population 0
# Generating initial population 1
# Generating initial population 2
# Generating initial population 3
# Generating initial population 4
# Generating initial population 5
# Generating initial population 6
# Generating initial population 7
# Generating initial population 8
# Generating initial population 9
# Generating initial population 10
# Generating initial population 11
# Generating initial population 12
# Generating initial population 13
# Generating initial population 14
# Generating initial population 15
# Generating initial population 16
# Generating initial population 17
# Generating initial population 18
# Generating initial population 19
# New best distance: 35682.24032855412 in generation 1
# New best distance: 34896.48845803145 in generation 2
# New best distance: 34896.48845803145 in generation 3
# New best distance: 34399.59280971356 in generation 4
# New best distance: 34399.59280971356 in generation 5
# New best distance: 34380.80444145993 in generation 6
# New best distance: 34380.80444145993 in generation 7
# New best distance: 34380.80444145993 in generation 8
# New best distance: 34380.80444145993 in generation 9
# New best distance: 34265.763359519595 in generation 10
# New best distance: 33881.79963612165 in generation 11
# New best distance: 33881.79963612165 in generation 12
# New best distance: 33881.79963612165 in generation 13
# New best distance: 33881.79963612165 in generation 14
# New best distance: 33881.79963612165 in generation 15
# New best distance: 33881.79963612165 in generation 16
# New best distance: 33881.79963612165 in generation 17
# New best distance: 33517.511692097876 in generation 18
# New best distance: 33517.511692097876 in generation 19
# New best distance: 33491.075239066166 in generation 20
# New best distance: 33491.075239066166 in generation 21
# New best distance: 33491.075239066166 in generation 22
# New best distance: 33491.075239066166 in generation 23
# New best distance: 33491.075239066166 in generation 24
# New best distance: 33491.075239066166 in generation 25
# New best distance: 33491.075239066166 in generation 26
# New best distance: 33491.075239066166 in generation 27
# New best distance: 33491.075239066166 in generation 28
# New best distance: 33191.90131332635 in generation 29
# New best distance: 33172.96570609852 in generation 30
# New best distance: 33172.96570609852 in generation 31
# New best distance: 32944.51027034424 in generation 32
# New best distance: 32944.51027034424 in generation 33
# New best distance: 32944.51027034424 in generation 34
# New best distance: 32944.51027034424 in generation 35
# New best distance: 32944.51027034424 in generation 36
# New best distance: 32944.51027034424 in generation 37
# New best distance: 32944.51027034424 in generation 38
# New best distance: 32884.78236487604 in generation 39
# New best distance: 32884.78236487604 in generation 40
# New best distance: 32884.78236487604 in generation 41
# New best distance: 32884.78236487604 in generation 42
# New best distance: 32884.78236487604 in generation 43
# New best distance: 32884.78236487604 in generation 44
# New best distance: 32884.78236487604 in generation 45
# New best distance: 32884.78236487604 in generation 46
# New best distance: 32884.78236487604 in generation 47
# New best distance: 32884.78236487604 in generation 48
# New best distance: 32884.78236487604 in generation 49
# New best distance: 32884.78236487604 in generation 50
# New best distance: 32789.26289888782 in generation 51
# New best distance: 32789.26289888782 in generation 52
# New best distance: 32789.26289888782 in generation 53
# New best distance: 32789.26289888782 in generation 54
# New best distance: 32789.26289888782 in generation 55
# New best distance: 32789.26289888782 in generation 56
# New best distance: 32753.73301089669 in generation 57
# New best distance: 32725.331731775434 in generation 58
# New best distance: 32725.331731775434 in generation 59
# New best distance: 32725.331731775434 in generation 60
# New best distance: 32725.331731775434 in generation 61
# New best distance: 32725.331731775434 in generation 62
# New best distance: 32725.331731775434 in generation 63
# New best distance: 32725.331731775434 in generation 64
# New best distance: 32725.331731775434 in generation 65
# New best distance: 32725.331731775434 in generation 66
# New best distance: 32725.331731775434 in generation 67
# New best distance: 32725.331731775434 in generation 68
# New best distance: 32725.331731775434 in generation 69
# New best distance: 32725.331731775434 in generation 70
# New best distance: 32689.843978489083 in generation 71
# New best distance: 32689.843978489083 in generation 72
# New best distance: 32689.843978489083 in generation 73
# New best distance: 32689.843978489083 in generation 74
# New best distance: 32689.843978489083 in generation 75
# New best distance: 32689.843978489083 in generation 76
# New best distance: 32654.844942868236 in generation 77
# New best distance: 32654.844942868236 in generation 78
# New best distance: 32654.844942868236 in generation 79
# New best distance: 32654.844942868236 in generation 80
# New best distance: 32654.844942868236 in generation 81
# New best distance: 32654.844942868236 in generation 82
# New best distance: 32654.844942868236 in generation 83
# New best distance: 32654.844942868236 in generation 84
# New best distance: 32423.927397452397 in generation 85
# New best distance: 32423.927397452397 in generation 86
# New best distance: 32423.927397452397 in generation 87
# New best distance: 32423.927397452397 in generation 88
# New best distance: 32423.927397452397 in generation 89
# New best distance: 32423.927397452397 in generation 90
# New best distance: 32423.927397452397 in generation 91
# New best distance: 32423.927397452397 in generation 92
# New best distance: 32423.927397452397 in generation 93
# New best distance: 32423.927397452397 in generation 94
# New best distance: 32423.927397452397 in generation 95
# New best distance: 32423.927397452397 in generation 96
# New best distance: 32423.927397452397 in generation 97
# New best distance: 32423.927397452397 in generation 98
# New best distance: 32423.927397452397 in generation 99
# New best distance: 32423.927397452397 in generation 100
# New best distance: 32235.9735203405 in generation 101
# New best distance: 32235.9735203405 in generation 102
# New best distance: 32235.9735203405 in generation 103
# New best distance: 32235.9735203405 in generation 104
# New best distance: 32235.9735203405 in generation 105
# New best distance: 32235.9735203405 in generation 106
# New best distance: 32235.9735203405 in generation 107
# New best distance: 32235.9735203405 in generation 108
# New best distance: 32235.9735203405 in generation 109
# New best distance: 32235.9735203405 in generation 110
# Intance: ./data/lab3/kroA200.txt, strategy: solve_evo, node: 1
# Generating initial population 0
# Generating initial population 1
# Generating initial population 2
# Generating initial population 3
# Generating initial population 4
# Generating initial population 5
# Generating initial population 6
# Generating initial population 7
# Generating initial population 8
# Generating initial population 9
# Generating initial population 10
# Generating initial population 11
# Generating initial population 12
# Generating initial population 13
# Generating initial population 14
# Generating initial population 15
# Generating initial population 16
# Generating initial population 17
# Generating initial population 18
# Generating initial population 19
# New best distance: 36542.136384729005 in generation 1
# New best distance: 35537.78283958032 in generation 2
# New best distance: 35489.44809898756 in generation 3
# New best distance: 35489.44809898756 in generation 4
# New best distance: 35489.44809898756 in generation 5
# New best distance: 34871.3568445361 in generation 6
# New best distance: 32147.353752120463 in generation 40
# New best distance: 32146.93463846439 in generation 41
# New best distance: 32146.93463846439 in generation 42
# New best distance: 32146.93463846439 in generation 43
# New best distance: 32146.93463846439 in generation 44
# New best distance: 32146.93463846439 in generation 45
# New best distance: 32146.93463846439 in generation 46
# New best distance: 32146.93463846439 in generation 47
# New best distance: 32146.93463846439 in generation 48
# New best distance: 32146.93463846439 in generation 49
# New best distance: 32146.93463846439 in generation 50
# New best distance: 32146.93463846439 in generation 51
# New best distance: 32146.93463846439 in generation 52
# New best distance: 32146.93463846439 in generation 53
# New best distance: 32146.93463846439 in generation 54
# New best distance: 32146.93463846439 in generation 55
# New best distance: 32138.77698312411 in generation 56
# New best distance: 32138.77698312411 in generation 57
# New best distance: 32138.77698312411 in generation 58
# New best distance: 32138.77698312411 in generation 59
# New best distance: 32138.77698312411 in generation 60
# New best distance: 32138.77698312411 in generation 61
# New best distance: 32044.97510277636 in generation 62
# New best distance: 32026.105645492793 in generation 63
# New best distance: 32026.105645492793 in generation 64
# New best distance: 32026.105645492793 in generation 65
# New best distance: 32026.105645492793 in generation 66
# New best distance: 32026.105645492793 in generation 67
# New best distance: 31939.86183741329 in generation 68
# New best distance: 31939.86183741329 in generation 69
# New best distance: 31939.86183741329 in generation 70
# New best distance: 31939.86183741329 in generation 71
# New best distance: 31939.86183741329 in generation 72
# New best distance: 31939.86183741329 in generation 73
# New best distance: 31939.86183741329 in generation 74
# New best distance: 31939.86183741329 in generation 75
# New best distance: 31939.86183741329 in generation 76
# New best distance: 31939.86183741329 in generation 77
# New best distance: 31939.86183741329 in generation 78
# New best distance: 31939.86183741329 in generation 79
# New best distance: 31939.86183741329 in generation 80
# New best distance: 31939.86183741329 in generation 81
# New best distance: 31939.86183741329 in generation 82
# New best distance: 31939.86183741329 in generation 83
# New best distance: 31939.86183741329 in generation 84
# New best distance: 31939.86183741329 in generation 85
# New best distance: 31939.86183741329 in generation 86
# New best distance: 31939.86183741329 in generation 87
# New best distance: 31939.86183741329 in generation 88
# New best distance: 31939.86183741329 in generation 89
# New best distance: 31939.86183741329 in generation 90
# New best distance: 31939.86183741329 in generation 91
# New best distance: 31939.86183741329 in generation 92
# New best distance: 31939.86183741329 in generation 93
# New best distance: 31939.86183741329 in generation 94
# New best distance: 31939.86183741329 in generation 95
# New best distance: 31939.86183741329 in generation 96
# New best distance: 31939.86183741329 in generation 97
# New best distance: 31939.86183741329 in generation 98
# New best distance: 31939.86183741329 in generation 99
# New best distance: 31939.86183741329 in generation 100
# New best distance: 31939.86183741329 in generation 101
# New best distance: 31939.86183741329 in generation 102
# New best distance: 31939.86183741329 in generation 103
# New best distance: 31939.86183741329 in generation 104
# New best distance: 31939.86183741329 in generation 105
# New best distance: 31939.86183741329 in generation 106
# Intance: ./data/lab3/kroA200.txt, strategy: solve_evo, node: 3
# Generating initial population 0
# Generating initial population 1
# Generating initial population 2
# Generating initial population 3
# Generating initial population 4
# Generating initial population 5
# Generating initial population 6
# Generating initial population 7
# Generating initial population 8
# 1  ./data/lab3/kroB200.txt  solve_evo  31952.467578   32370.555798
#
#    max_distance
# 0  32235.973520
# 1  33039.426538

# %% [markdown]
# Zadanie 6. Testy globalnej wypukłości.

# %%
instances = ['./data/lab1/kroA100.txt', './data/lab1/kroB100.txt']
# instances = ['./data/lab3/kroA200.txt', './data/lab3/kroB200.txt']
# instances = ['./data/lab3/kroA200.txt']
# instance_size = 200
instance_size = 100

def get_results():
    results = []
    distances = []
    for instance_index, instance in enumerate(instances):
        results.append([])
        distances.append([])
        with open(instance) as f:
            data = f.read()
        data = data.split('\n')
        data = pd.DataFrame([i.split(' ') for i in data])
        data = data.drop(0, axis=1)
        data = data.drop(instance_size, axis=0)

        points_matrix = data.to_numpy()
        points_matrix = points_matrix.astype(int)
        matrix = []
        for i in range(instance_size):
            matrix.append([])
            for j in range(instance_size):
                matrix[i].append(points_matrix[i, :] - points_matrix[j, :])
        matrix = np.array(matrix)
        distance_matrix = np.sqrt(np.square(matrix[:, :, 0]) + np.square(matrix[:, :, 1]))

        for i in range(distance_matrix.shape[0]):
            distance_matrix[i, i] = np.inf

        for i in range(1000):
            print(f'Intance: {instance}, node: {i}')
            initial_cycles = solve_random(distance_matrix)
            cycles = solve_greedy(distance_matrix, initial_cycles, neighborhood='edges')
            distances[instance_index].append(calc_distance_sum(cycles[0], distance_matrix) + calc_distance_sum(cycles[1], distance_matrix))
            cycles[0] = cycles[0][:-1]
            cycles[1] = cycles[1][:-1]
            results[instance_index].append(cycles)
    return results, distances

# %%
cycles, distances = get_results()
# Out:
# Intance: ./data/lab1/kroA100.txt, node: 0
# Intance: ./data/lab1/kroA100.txt, node: 1
# Intance: ./data/lab1/kroA100.txt, node: 2
# Intance: ./data/lab1/kroA100.txt, node: 3
# Intance: ./data/lab1/kroA100.txt, node: 4
# Intance: ./data/lab1/kroA100.txt, node: 5
# Intance: ./data/lab1/kroA100.txt, node: 6
# Intance: ./data/lab1/kroA100.txt, node: 7
# Intance: ./data/lab1/kroA100.txt, node: 8
# Intance: ./data/lab1/kroA100.txt, node: 9
# Intance: ./data/lab1/kroA100.txt, node: 10
# Intance: ./data/lab1/kroA100.txt, node: 11
# Intance: ./data/lab1/kroA100.txt, node: 12
# Intance: ./data/lab1/kroA100.txt, node: 13
# Intance: ./data/lab1/kroA100.txt, node: 14
# Intance: ./data/lab1/kroA100.txt, node: 15
# Intance: ./data/lab1/kroA100.txt, node: 16
# Intance: ./data/lab1/kroA100.txt, node: 17
# Intance: ./data/lab1/kroA100.txt, node: 18
# Intance: ./data/lab1/kroA100.txt, node: 19
# Intance: ./data/lab1/kroA100.txt, node: 20
# Intance: ./data/lab1/kroA100.txt, node: 21
# Intance: ./data/lab1/kroA100.txt, node: 22
# Intance: ./data/lab1/kroA100.txt, node: 23
# Intance: ./data/lab1/kroA100.txt, node: 24
# Intance: ./data/lab1/kroA100.txt, node: 25
# Intance: ./data/lab1/kroA100.txt, node: 26
# Intance: ./data/lab1/kroA100.txt, node: 27
# Intance: ./data/lab1/kroA100.txt, node: 28
# Intance: ./data/lab1/kroB100.txt, node: 989
# Intance: ./data/lab1/kroB100.txt, node: 990
# Intance: ./data/lab1/kroB100.txt, node: 991
# Intance: ./data/lab1/kroB100.txt, node: 992
# Intance: ./data/lab1/kroB100.txt, node: 993
# Intance: ./data/lab1/kroB100.txt, node: 994
# Intance: ./data/lab1/kroB100.txt, node: 995
# Intance: ./data/lab1/kroB100.txt, node: 996
# Intance: ./data/lab1/kroB100.txt, node: 997
# Intance: ./data/lab1/kroB100.txt, node: 998
# Intance: ./data/lab1/kroB100.txt, node: 999

# %%
# calculate similarity
def calculate_vertex_similarity(solution1, solution2):
    similarity = 0

    for cycle1 in solution1:
        max_common_vertices = 0

        for cycle2 in solution2:
            common_vertices = len(set(cycle1) & set(cycle2))

            if common_vertices > max_common_vertices:
                max_common_vertices = common_vertices

        similarity += max_common_vertices

    return similarity

def calculate_edge_similarity(solution1, solution2):
    similarity = 0

    for cycle1 in solution1:
        max_common_edges = 0

        for cycle2 in solution2:
            common_edges = count_common_edges(cycle1, cycle2)

            if common_edges > max_common_edges:
                max_common_edges = common_edges

        similarity += max_common_edges

    return similarity


def count_common_edges(cycle1, cycle2):
    common_edges = 0
    cycle1_edges = get_edges(cycle1)
    cycle2_edges = get_edges(cycle2)

    for edge in cycle1_edges:
        if edge in cycle2_edges:
            common_edges += 1

    return common_edges


def get_edges(cycle):
    edges = set()

    for i in range(len(cycle) - 1):
        edge = (cycle[i], cycle[i + 1])
        edges.add(edge)

    # Dodaj krawędź łączącą ostatni wierzchołek z pierwszym wierzchołkiem
    last_edge = (cycle[-1], cycle[0])
    edges.add(last_edge)

    return edges

# %%
vertex_similarities = []
edge_similarities = []

for instance_index, instance in enumerate(instances):
    vertex_similarities.append([])
    edge_similarities.append([])
    for i in range(len(cycles[0])):
        vertex_similarities[instance_index].append([])
        edge_similarities[instance_index].append([])
        for j in range(len(cycles[0])):
            vertex_similarities[instance_index][i].append(calculate_vertex_similarity(cycles[0][i], cycles[0][j]))
            edge_similarities[instance_index][i].append(calculate_edge_similarity(cycles[0][i], cycles[0][j]))
        

vertex_similarities = np.array(vertex_similarities)
edge_similarities = np.array(edge_similarities)

best_solution = np.min(distances, axis=1)
print(f'BEST SOLUTIONS: {best_solutions}')
best_solution_index = np.argmin(distances, axis=1)
print(f'BEST SOLUTIONS INDEX: {best_solution_index}')

mean_vertex_similarities = (np.sum(vertex_similarities, axis=1) - np.max(vertex_similarities, axis=1)) / (vertex_similarities.shape[1] - 1)
print(f'MEAN VERTEX SIMILARITIES: {mean_vertex_similarities}')

mean_edge_similarities = (np.sum(edge_similarities, axis=1) - np.max(edge_similarities, axis=1)) / (edge_similarities.shape[1] - 1)
print(f'MEAN EDGE SIMILARITIES: {mean_edge_similarities}')

vertex_similarities_to_best = []
edge_similarities_to_best = []

for instance_index, instance in enumerate(instances):
    vertex_similarities_to_best.append([])
    edge_similarities_to_best.append([])
    for i in range(len(cycles[0])):
        vertex_similarities_to_best[instance_index].append(vertex_similarities[instance_index][i][best_solution_index[instance_index]])
        edge_similarities_to_best[instance_index].append(edge_similarities[instance_index][i][best_solution_index[instance_index]])

vertex_similarities_to_best = np.array(vertex_similarities_to_best)
edge_similarities_to_best = np.array(edge_similarities_to_best)

print(f'VERTEX SIMILARITIES TO BEST: {vertex_similarities_to_best}')
print(f'EDGE SIMILARITIES TO BEST: {edge_similarities_to_best}')
# Out:
# BEST SOLUTIONS: [27116.88220552 26190.69360387]
# BEST SOLUTIONS INDEX: [421 456]
# MEAN VERTEX SIMILARITIES: [[56.71871872 55.57357357 55.28928929 ... 56.28028028 55.88188188
#   55.36736737]
#  [56.71871872 55.57357357 55.28928929 ... 56.28028028 55.88188188
#   55.36736737]]
# MEAN EDGE SIMILARITIES: [[19.88588589 21.21721722 17.36436436 ... 16.96096096 16.45045045
#   15.84884885]
#  [19.88588589 21.21721722 17.36436436 ... 16.96096096 16.45045045
#   15.84884885]]
# VERTEX SIMILARITIES TO BEST: [[54 52 52 ... 54 54 50]
#  [66 56 58 ... 62 52 54]]
# EDGE SIMILARITIES TO BEST: [[28 18 24 ... 25 24 15]
#  [20 17 13 ... 24 26 22]]

# %%
plt.style.use('ggplot')

for i in range(len(instances)):
    plt.scatter(distances[i], mean_vertex_similarities[i])
    plt.xlabel('Distance')
    plt.ylabel('Mean vertex similarity')
    plt.title('Distance vs mean vertex similarity')
    plt.show()
    print(f'Correlation coefficient: {np.corrcoef(distances[i], mean_vertex_similarities[i])[0][1]}')

    plt.scatter(distances[i], mean_edge_similarities[i])
    plt.xlabel('Distance')
    plt.ylabel('Mean edge similarity')
    plt.title('Distance vs mean edge similarity')
    plt.show()
    print(f'Correlation coefficient: {np.corrcoef(distances[i], mean_edge_similarities[i])[0][1]}')

    distances_copy = distances[i].copy()
    vertex_similarities_to_best_copy = vertex_similarities_to_best[i].copy()
    edge_similarities_to_best_copy = edge_similarities_to_best[i].copy()
    # remove best solution
    distances_copy = np.delete(distances_copy, best_solution_index[i])
    vertex_similarities_to_best_copy = np.delete(vertex_similarities_to_best_copy, best_solution_index[i])
    edge_similarities_to_best_copy = np.delete(edge_similarities_to_best_copy, best_solution_index[i])

    plt.scatter(distances_copy, vertex_similarities_to_best_copy)
    plt.xlabel('Distance')
    plt.ylabel('Vertex similarity to best')
    plt.title('Distance vs vertex similarity to the best')
    plt.show()
    print(f'Correlation coefficient: {np.corrcoef(distances_copy, vertex_similarities_to_best_copy)[0][1]}')

    plt.scatter(distances_copy, edge_similarities_to_best_copy)
    plt.xlabel('Distance')
    plt.ylabel('Edge similarity to best')
    plt.title('Distance vs edge similarity to the best')
    plt.show()
    print(f'Correlation coefficient: {np.corrcoef(distances_copy, edge_similarities_to_best_copy)[0][1]}')
# Out:
# Correlation coefficient: -0.6730950787728017
# Correlation coefficient: -0.41963395489298944
# Correlation coefficient: -0.1839239742605391
# Correlation coefficient: -0.16857990106696885
# Correlation coefficient: 0.0015916139454050227
# Correlation coefficient: 0.04481532131932567
# Correlation coefficient: -0.01879436684661396
# Correlation coefficient: -0.010306430020170617
